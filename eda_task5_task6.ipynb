# %% [markdown]
# ### Delays Percentage

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flights_tsk = pd.read_csv('data/flights_no_outlier_iqr_time.csv')

# %%
#percentage of delays cause by anything other
#than the arrival delays

dep_del_no_arrival_delay = flights_tsk5.loc[(flights_tsk5['arr_delay'] == 0) & (flights_tsk5['dep_delay'] > 0)].dep_delay.sum()
all_dep_delays =  flights_tsk5.loc[(flights_tsk5['dep_delay'] >=0)].dep_delay.sum()
percentage = (dep_del_no_arrival_delay)/(all_dep_delays) * 100
print("Percentage of delays with no arrival delays:", percentage)
# Out:
# Percentage of delays with no arrival delays: 2.6729207292511137

# %% [markdown]
# ### Top States in Terms of Air Traffic

# %%
top_states_number_flights = flights_tsk.groupby('origin_city_name')['taxi_in'].count().sort_values(ascending=False).head(18)
sum_top_number_flights = top_states_number_flights.values.sum()
total_number_flightes = flights_tsk.groupby('origin_city_name')['taxi_in'].count().sort_values(ascending=False).sum()

# %%
fig, axes = plt.subplots(figsize=(15,10))
sns.barplot(ax=axes, x=(s.values/total_number_flightes)*100, y=s.index,color='b')
axes.set_title('Average Taxi-out Time For Different Hours')
axes.set_xlabel('Numbers of ')
axes.set_ylabel('Average Time(min)')
plt.show()

# %%
#total percentage contribution from 18 states
percentage = sum_top_number_flights/total_number_flightes* 100
print('top 18 states contribute {} percentage of the air traffic'.format(percentage))
# Out:
# top 18 states contribute 52.70715677014544 percentage of the air traffic
